# %%
from packaging.version import Version
from importlib.metadata import version, PackageNotFoundError

try:
    sempy_labs_version = version('semantic-link-labs')
except PackageNotFoundError:
    sempy_labs_version = None

if sempy_labs_version is None or Version(sempy_labs_version) < Version("0.9.8"):
    get_ipython().run_line_magic('pip', 'install semantic-link-labs')
# Out:
# StatementMeta(, 2da6b45c-05a6-4fe3-a188-485b3e5d8c43, 3, Finished, Available, Finished, False)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.8/859.8 kB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 114.0 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 47.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 63.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 2024.9.1
#     Uninstalling azure-core-2024.9.1:
#       Successfully uninstalled azure-core-2024.9.1
#   Attempting uninstall: semantic-link-sempy
# ...

# %%
import sempy_labs as sl
import sempy_labs.report as slr

start_workspace = 'Kontroling - PROD'
report= 'Izveštaj o produkciji mart 2026 PROD'
dataset_name = 'Izveštaj o produkciji mart 2026 PROD'

destination_dataset_workspace = 'Sem. modeli - PROD'
destination_dataset_name = 'Izveštaj o produkciji mart 2026 PROD'

remove_original_dataset = True
overwrite = True
# Out:
# StatementMeta(, 2da6b45c-05a6-4fe3-a188-485b3e5d8c43, 4, Finished, Available, Finished, False)

# %%
#copying the semantic model
sl.deploy_semantic_model(source_dataset=dataset_name
    , source_workspace=start_workspace
    , target_dataset=destination_dataset_name
    , target_workspace=destination_dataset_workspace
    , refresh_target_dataset=True
    , overwrite=overwrite)

#rebinding the report
slr.report_rebind(report=report
, dataset=destination_dataset_name
, report_workspace=start_workspace
, dataset_workspace=destination_dataset_workspace)

#trying to delete the original dataset
if remove_original_dataset:
    try: 
        sl.delete_semantic_model(dataset=dataset_name, workspace=start_workspace)
    except:
        print("Failed to delete original semantic model. Please go manually delete")
# Out:
# StatementMeta(, 2da6b45c-05a6-4fe3-a188-485b3e5d8c43, 6, Finished, Available, Finished, False)
# 🟢 The 'Izveštaj o produkciji mart 2026 PROD' semantic model has been updated within the 'Sem. modeli - PROD' workspace.
# 🟢 The 'Izveštaj o produkciji mart 2026 PROD' report within the 'Kontroling - PROD' workspace has been successfully rebinded to the 'Izveštaj o produkciji mart 2026 PROD' semantic model within the 'Sem. modeli - PROD' workspace.
# 🟢 The 'Izveštaj o produkciji mart 2026 PROD' SemanticModel has been successfully deleted from the 'Kontroling - PROD' workspace.
